# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from time import time

# %%
act_train_data = pd.read_csv("./act_train.csv", 
                             dtype={'people_id': np.str, 'activity_id': np.str, 'outcome': np.int8}, 
                             parse_dates=['date'])
act_test_data  = pd.read_csv("./act_test.csv", 
                             dtype={'people_id': np.str, 'activity_id': np.str}, parse_dates=['date'])
people_data    = pd.read_csv("./people.csv", 
                             dtype={'people_id': np.str, 'activity_id': np.str, 'char_38': np.int32}, 
                             parse_dates=['date'])

# %%
act_whole = pd.concat([act_train_data, act_test_data], ignore_index=True)
del act_train_data, act_test_data

act_whole = act_whole[['activity_id', 'people_id', 'outcome', 'date']]
act_whole[2197285:2197300]
# Out:
#           activity_id   people_id  outcome       date
# 2197285  act2_4581579   ppl_99994      1.0 2023-01-13
# 2197286  act2_4668076   ppl_99994      1.0 2023-06-16
# 2197287  act2_4743548   ppl_99994      1.0 2023-03-30
# 2197288   act2_536973   ppl_99994      1.0 2023-01-19
# 2197289   act2_688656   ppl_99994      1.0 2023-05-02
# 2197290   act2_715089   ppl_99994      1.0 2023-06-15
# 2197291   act1_249281  ppl_100004      NaN 2022-07-20
# 2197292   act2_230855  ppl_100004      NaN 2022-07-20
# 2197293   act1_240724   ppl_10001      NaN 2022-10-14
# 2197294    act1_83552   ppl_10001      NaN 2022-11-27
# 2197295  act2_1043301   ppl_10001      NaN 2022-10-15
# 2197296   act2_112890   ppl_10001      NaN 2022-11-27
# 2197297  act2_1169930   ppl_10001      NaN 2022-10-15
# 2197298  act2_1924448   ppl_10001      NaN 2022-10-15
# 2197299  act2_1953554   ppl_10001      NaN 2022-10-15

# %%
act_merged = act_whole.merge(people_data, on='people_id', how='left')
del act_whole, people_data
act_merged[:3]
# Out:
#     activity_id people_id  outcome     date_x  char_1      group_1  char_2  \
# 0  act2_1734928   ppl_100      0.0 2023-08-26  type 2  group 17304  type 2
# 1  act2_2434093   ppl_100      0.0 2022-09-27  type 2  group 17304  type 2
# 2  act2_3404049   ppl_100      0.0 2022-09-27  type 2  group 17304  type 2
#
#       date_y  char_3  char_4   ...   char_29 char_30 char_31 char_32 char_33  \
# 0 2021-06-29  type 5  type 5   ...     False    True    True   False   False
# 1 2021-06-29  type 5  type 5   ...     False    True    True   False   False
# 2 2021-06-29  type 5  type 5   ...     False    True    True   False   False
#
#   char_34 char_35 char_36 char_37 char_38
# 0    True    True    True   False      36
# 1    True    True    True   False      36
# 2    True    True    True   False      36
#
# [3 rows x 44 columns]

# %%
act_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2695978 entries, 0 to 2695977
# Data columns (total 44 columns):
# activity_id    object
# people_id      object
# outcome        float64
# date_x         datetime64[ns]
# char_1         object
# group_1        object
# char_2         object
# date_y         datetime64[ns]
# char_3         object
# char_4         object
# char_5         object
# char_6         object
# char_7         object
# char_8         object
# char_9         object
# char_10        bool
# char_11        bool
# char_12        bool
# char_13        bool
# char_14        bool
# char_15        bool
# char_16        bool
# char_17        bool
# char_18        bool
# char_19        bool
# char_20        bool
# char_21        bool
# char_22        bool
# char_23        bool
# char_24        bool
# char_25        bool
# char_26        bool
# char_27        bool
# char_28        bool
# char_29        bool
# char_30        bool
# char_31        bool
# char_32        bool
# char_33        bool
# char_34        bool
# char_35        bool
# char_36        bool
# char_37        bool
# char_38        int32
# dtypes: bool(28), datetime64[ns](2), float64(1), int32(1), object(12)
# memory usage: 411.4+ MB

# %%
# %%time
allDays = pd.Series(pd.date_range(act_merged['date_x'].min(), act_merged['date_x'].max()))
nb_days = len(allDays)
# create all combinations of companies (group_1) and dates
allCompDays = [pd.concat([pd.Series([g]*nb_days), allDays], axis=1)
               for g in sorted(act_merged[:2197291]['group_1'].unique())]
allCompDays = pd.concat(allCompDays, ignore_index=True)
allCompDays.columns = ['group_1', 'date_act']
# Out:
# CPU times: user 26.5 s, sys: 745 ms, total: 27.3 s
# Wall time: 27.4 s

# %%
allCompDays.head()
# Out:
#    group_1   date_act
# 0  group 1 2022-07-17
# 1  group 1 2022-07-18
# 2  group 1 2022-07-19
# 3  group 1 2022-07-20
# 4  group 1 2022-07-21

# %%
meanByCompDays = pd.DataFrame(act_merged.groupby(['group_1', 'date_x'])['outcome'].mean())
meanByCompDays.reset_index(inplace=True)
meanByCompDays.head()
# Out:
#     group_1     date_x  outcome
# 0   group 1 2022-11-27      0.0
# 1  group 10 2022-08-19      0.0
# 2  group 10 2022-08-20      0.0
# 3  group 10 2022-08-24      0.0
# 4  group 10 2022-08-25      0.0

# %%
allCompDays = allCompDays.merge(meanByCompDays, left_on=['group_1', 'date_act'], 
                                right_on=['group_1', 'date_x'], how='left').drop('date_x', axis=1)
allCompDays.head()
# Out:
#    group_1   date_act  outcome
# 0  group 1 2022-07-17      NaN
# 1  group 1 2022-07-18      NaN
# 2  group 1 2022-07-19      NaN
# 3  group 1 2022-07-20      NaN
# 4  group 1 2022-07-21      NaN

# %%
# function to interpolate unknown values
def interpolate(x):
    # Find all non-NA indices, combine them with outside borders
    borders = np.array([0] + list(np.where(~pd.isnull(x))[0]) + [len(x)])
    # establish forward and backward - looking indexes
    forward_border = borders[1:]
    backward_border = borders[:-1]
    
    # prepare vectors for filling
    forward_border_x = x.iloc[borders[1:-1]].values
    forward_border_x = np.append(forward_border_x, [abs(forward_border_x[-1] - 0.1)])
    backward_border_x = x.iloc[borders[1:-1]].values
    backward_border_x = np.append([abs(forward_border_x[0] - 0.1)], backward_border_x)
    
    # generate fill vectors
    forward_x_fill = np.repeat(forward_border_x, forward_border-backward_border)
    backward_x_fill = np.repeat(backward_border_x, forward_border-backward_border)
    
    #linear interpolation
    vec = (forward_x_fill + backward_x_fill)/2.
  
    x[pd.isnull(x)] = vec[pd.isnull(x)]
    return x

# %%
# %%time
out_interp = allCompDays.groupby('group_1')['outcome'].apply(interpolate)
allCompDays['outcome'] = out_interp
del out_interp
# Out:
# CPU times: user 2min 15s, sys: 1.63 s, total: 2min 16s
# Wall time: 2min 17s

# %%
allCompDays.head()
# Out:
#    group_1   date_act  outcome
# 0  group 1 2022-07-17     0.05
# 1  group 1 2022-07-18     0.05
# 2  group 1 2022-07-19     0.05
# 3  group 1 2022-07-20     0.05
# 4  group 1 2022-07-21     0.05

# %%
# %%time
act_merged = act_merged.merge(allCompDays, left_on=['group_1', 'date_x'], 
                              right_on=['group_1', 'date_act'], how='left')
# Out:
# CPU times: user 4.13 s, sys: 2.23 s, total: 6.35 s
# Wall time: 7.05 s

# %%
act_merged.head()
# Out:
#     activity_id people_id  outcome_x     date_x  char_1      group_1  char_2  \
# 0  act2_1734928   ppl_100        0.0 2023-08-26  type 2  group 17304  type 2
# 1  act2_2434093   ppl_100        0.0 2022-09-27  type 2  group 17304  type 2
# 2  act2_3404049   ppl_100        0.0 2022-09-27  type 2  group 17304  type 2
# 3  act2_3651215   ppl_100        0.0 2023-08-04  type 2  group 17304  type 2
# 4  act2_4109017   ppl_100        0.0 2023-08-26  type 2  group 17304  type 2
#
#       date_y  char_3  char_4    ...    char_31 char_32 char_33 char_34  \
# 0 2021-06-29  type 5  type 5    ...       True   False   False    True
# 1 2021-06-29  type 5  type 5    ...       True   False   False    True
# 2 2021-06-29  type 5  type 5    ...       True   False   False    True
# 3 2021-06-29  type 5  type 5    ...       True   False   False    True
# 4 2021-06-29  type 5  type 5    ...       True   False   False    True
#
#   char_35 char_36 char_37 char_38   date_act outcome_y
# 0    True    True   False      36 2023-08-26       0.0
# 1    True    True   False      36 2022-09-27       0.0
# 2    True    True   False      36 2022-09-27       0.0
# 3    True    True   False      36 2023-08-04       0.0
# 4    True    True   False      36 2023-08-26       0.0
#
# [5 rows x 46 columns]

# %%
act_merged[pd.isnull(act_merged['outcome_y'])]
# Out:
#           activity_id   people_id  outcome_x     date_x  char_1      group_1  \
# 2197513  act2_2277070  ppl_100179        NaN 2022-09-02  type 2  group 23919
# 2197514  act2_3152044  ppl_100179        NaN 2022-09-02  type 2  group 23919
# 2197777  act2_1008806  ppl_100322        NaN 2023-01-20  type 2  group 21374
# 2197778  act2_2022187  ppl_100322        NaN 2023-01-20  type 2  group 21374
# 2197779  act2_2182495  ppl_100322        NaN 2023-02-18  type 2  group 21374
# 2197780  act2_2868576  ppl_100322        NaN 2023-02-15  type 2  group 21374
# 2197781  act2_3947881  ppl_100322        NaN 2022-09-27  type 2  group 21374
# 2197782  act2_4071983  ppl_100322        NaN 2022-10-13  type 2  group 21374
# 2197783  act2_4556794  ppl_100322        NaN 2023-02-16  type 2  group 21374
# 2197784   act2_471550  ppl_100322        NaN 2023-01-11  type 2  group 21374
# 2197785  act2_4758978  ppl_100322        NaN 2023-03-03  type 2  group 21374
# 2197786   act2_534352  ppl_100322        NaN 2023-01-24  type 2  group 21374
# 2197787   act2_927116  ppl_100322        NaN 2023-01-24  type 2  group 21374
# 2197895    act2_12977  ppl_100390        NaN 2023-06-21  type 2  group 40411
# 2197896  act2_1467972  ppl_100390        NaN 2022-11-24  type 2  group 40411
# 2197897  act2_1590393  ppl_100390        NaN 2023-02-10  type 2  group 40411
# 2197898  act2_1620689  ppl_100390        NaN 2022-11-26  type 2  group 40411
# 2197899   act2_163112  ppl_100390        NaN 2023-02-11  type 2  group 40411
# 2197900  act2_1848075  ppl_100390        NaN 2023-02-14  type 2  group 40411
# 2197901   act2_187374  ppl_100390        NaN 2023-02-28  type 2  group 40411
# 2197902  act2_2315197  ppl_100390        NaN 2023-02-09  type 2  group 40411
# 2197903    act2_23223  ppl_100390        NaN 2023-04-01  type 2  group 40411
# 2197904  act2_2467693  ppl_100390        NaN 2022-11-23  type 2  group 40411
# 2197905  act2_2483357  ppl_100390        NaN 2023-02-03  type 2  group 40411
# 2197906  act2_2514494  ppl_100390        NaN 2023-02-10  type 2  group 40411
# 2197907  act2_2686175  ppl_100390        NaN 2023-03-27  type 2  group 40411
# 2197908  act2_2715959  ppl_100390        NaN 2023-03-02  type 2  group 40411
# 2197909  act2_2744590  ppl_100390        NaN 2023-03-23  type 2  group 40411
# 2197910   act2_283422  ppl_100390        NaN 2023-03-24  type 2  group 40411
# 2197911  act2_2902802  ppl_100390        NaN 2022-11-23  type 2  group 40411
# ...               ...         ...        ...        ...     ...          ...
# 2695701  act2_3144232   ppl_99669        NaN 2022-12-17  type 2  group 36251
# 2695702  act2_3237492   ppl_99669        NaN 2022-12-17  type 2  group 36251
# 2695703  act2_3433692   ppl_99669        NaN 2023-07-18  type 2  group 36251
# 2695704    act2_57863   ppl_99669        NaN 2023-03-22  type 2  group 36251
# 2695705   act2_623380   ppl_99669        NaN 2023-07-18  type 2  group 36251
# 2695706   act2_677462   ppl_99669        NaN 2022-10-28  type 2  group 36251
# 2695804  act2_1858011    ppl_9981        NaN 2023-02-15  type 2  group 43668
# 2695805  act2_2523447    ppl_9981        NaN 2023-02-15  type 2  group 43668
# 2695806  act2_2684320    ppl_9981        NaN 2023-02-16  type 2  group 43668
# 2695807  act2_2818081    ppl_9981        NaN 2023-02-14  type 2  group 43668
# 2695808  act2_3206088    ppl_9981        NaN 2023-02-15  type 2  group 43668
# 2695809  act2_3575563    ppl_9981        NaN 2023-02-16  type 2  group 43668
# 2695810   act2_443541    ppl_9981        NaN 2023-02-15  type 2  group 43668
# 2695894   act1_141326   ppl_99856        NaN 2022-10-16  type 2  group 19920
# 2695895   act1_224584   ppl_99856        NaN 2022-11-03  type 2  group 19920
# 2695896  act2_1247562   ppl_99856        NaN 2022-11-12  type 2  group 19920
# 2695897  act2_1304948   ppl_99856        NaN 2022-11-12  type 2  group 19920
# 2695898  act2_1664540   ppl_99856        NaN 2022-11-05  type 2  group 19920
# 2695899  act2_1736583   ppl_99856        NaN 2022-11-12  type 2  group 19920
# 2695900  act2_1874357   ppl_99856        NaN 2022-11-03  type 2  group 19920
# 2695901  act2_2223896   ppl_99856        NaN 2022-07-26  type 2  group 19920
# 2695902  act2_2344680   ppl_99856        NaN 2022-11-05  type 2  group 19920
# 2695903   act2_262347   ppl_99856        NaN 2022-11-12  type 2  group 19920
# 2695904  act2_2771437   ppl_99856        NaN 2022-10-16  type 2  group 19920
# 2695905  act2_3448457   ppl_99856        NaN 2022-10-16  type 2  group 19920
# 2695906   act2_396879   ppl_99856        NaN 2022-11-03  type 2  group 19920
# 2695907  act2_4002164   ppl_99856        NaN 2022-11-05  type 2  group 19920
# 2695908    act2_67088   ppl_99856        NaN 2022-11-12  type 2  group 19920
# 2695909   act2_776478   ppl_99856        NaN 2022-07-26  type 2  group 19920
# 2695910   act2_998922   ppl_99856        NaN 2022-07-26  type 2  group 19920
#
#          char_2     date_y   char_3   char_4    ...    char_31 char_32  \
# 2197513  type 3 2021-07-22   type 9   type 6    ...      False   False
# 2197514  type 3 2021-07-22   type 9   type 6    ...      False   False
# 2197777  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197778  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197779  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197780  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197781  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197782  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197783  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197784  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197785  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197786  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197787  type 3 2021-01-28  type 15   type 6    ...      False   False
# 2197895  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197896  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197897  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197898  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197899  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197900  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197901  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197902  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197903  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197904  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197905  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197906  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197907  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197908  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197909  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197910  type 3 2022-11-22  type 15   type 2    ...       True    True
# 2197911  type 3 2022-11-22  type 15   type 2    ...       True    True
# ...         ...        ...      ...      ...    ...        ...     ...
# 2695701  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695702  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695703  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695704  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695705  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695706  type 3 2022-08-27  type 15   type 5    ...      False   False
# 2695804  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695805  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695806  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695807  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695808  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695809  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695810  type 3 2023-02-14  type 40  type 25    ...      False   False
# 2695894  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695895  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695896  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695897  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695898  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695899  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695900  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695901  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695902  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695903  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695904  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695905  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695906  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695907  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695908  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695909  type 3 2020-10-15   type 5   type 5    ...      False   False
# 2695910  type 3 2020-10-15   type 5   type 5    ...      False   False
#
#         char_33 char_34 char_35 char_36 char_37 char_38 date_act outcome_y
# 2197513   False   False   False   False   False       0      NaT       NaN
# 2197514   False   False   False   False   False       0      NaT       NaN
# 2197777   False   False   False   False   False      70      NaT       NaN
# 2197778   False   False   False   False   False      70      NaT       NaN
# 2197779   False   False   False   False   False      70      NaT       NaN
# 2197780   False   False   False   False   False      70      NaT       NaN
# 2197781   False   False   False   False   False      70      NaT       NaN
# 2197782   False   False   False   False   False      70      NaT       NaN
# 2197783   False   False   False   False   False      70      NaT       NaN
# 2197784   False   False   False   False   False      70      NaT       NaN
# 2197785   False   False   False   False   False      70      NaT       NaN
# 2197786   False   False   False   False   False      70      NaT       NaN
# 2197787   False   False   False   False   False      70      NaT       NaN
# 2197895    True    True    True    True    True      99      NaT       NaN
# 2197896    True    True    True    True    True      99      NaT       NaN
# 2197897    True    True    True    True    True      99      NaT       NaN
# 2197898    True    True    True    True    True      99      NaT       NaN
# 2197899    True    True    True    True    True      99      NaT       NaN
# 2197900    True    True    True    True    True      99      NaT       NaN
# 2197901    True    True    True    True    True      99      NaT       NaN
# 2197902    True    True    True    True    True      99      NaT       NaN
# 2197903    True    True    True    True    True      99      NaT       NaN
# 2197904    True    True    True    True    True      99      NaT       NaN
# 2197905    True    True    True    True    True      99      NaT       NaN
# 2197906    True    True    True    True    True      99      NaT       NaN
# 2197907    True    True    True    True    True      99      NaT       NaN
# 2197908    True    True    True    True    True      99      NaT       NaN
# 2197909    True    True    True    True    True      99      NaT       NaN
# 2197910    True    True    True    True    True      99      NaT       NaN
# 2197911    True    True    True    True    True      99      NaT       NaN
# ...         ...     ...     ...     ...     ...     ...      ...       ...
# 2695701   False   False   False   False   False      84      NaT       NaN
# 2695702   False   False   False   False   False      84      NaT       NaN
# 2695703   False   False   False   False   False      84      NaT       NaN
# 2695704   False   False   False   False   False      84      NaT       NaN
# 2695705   False   False   False   False   False      84      NaT       NaN
# 2695706   False   False   False   False   False      84      NaT       NaN
# 2695804   False   False   False   False   False      80      NaT       NaN
# 2695805   False   False   False   False   False      80      NaT       NaN
# 2695806   False   False   False   False   False      80      NaT       NaN
# 2695807   False   False   False   False   False      80      NaT       NaN
# 2695808   False   False   False   False   False      80      NaT       NaN
# 2695809   False   False   False   False   False      80      NaT       NaN
# 2695810   False   False   False   False   False      80      NaT       NaN
# 2695894   False   False   False   False   False      85      NaT       NaN
# 2695895   False   False   False   False   False      85      NaT       NaN
# 2695896   False   False   False   False   False      85      NaT       NaN
# 2695897   False   False   False   False   False      85      NaT       NaN
# 2695898   False   False   False   False   False      85      NaT       NaN
# 2695899   False   False   False   False   False      85      NaT       NaN
# 2695900   False   False   False   False   False      85      NaT       NaN
# 2695901   False   False   False   False   False      85      NaT       NaN
# 2695902   False   False   False   False   False      85      NaT       NaN
# 2695903   False   False   False   False   False      85      NaT       NaN
# 2695904   False   False   False   False   False      85      NaT       NaN
# 2695905   False   False   False   False   False      85      NaT       NaN
# 2695906   False   False   False   False   False      85      NaT       NaN
# 2695907   False   False   False   False   False      85      NaT       NaN
# 2695908   False   False   False   False   False      85      NaT       NaN
# 2695909   False   False   False   False   False      85      NaT       NaN
# 2695910   False   False   False   False   False      85      NaT       NaN
#
# [69073 rows x 46 columns]

# %%
submit = act_merged[2197291:][['activity_id', 'outcome_y']]
submit['outcome_y'][pd.isnull(submit['outcome_y'])] = submit['outcome_y'][~pd.isnull(submit['outcome_y'])].mean()
submit.columns = ['activity_id', 'outcome']
submit.to_csv('Submission_leak.csv', index=False)

# %% [markdown]
# The LB score is ~0.987.
